# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
# %matplotlib inline
import matplotlib.pyplot as plt
from utils import *
from ops import *
from dcgan import DCGAN
import numpy as np
import tensorflow as tf
from iwgan import IWGAN

# Specifiy model checkpoint directory & samples directory
checkpoint_dir = 'checkpoint'
samples_dir = 'samples'

tf.reset_default_graph()
# config = tf.ConfigProto(allow_soft_placement = True)
# sess = tf.Session(config = config)
# sess = tf.InteractiveSession(config=tf.ConfigProto(device_count={'GPU':0}))
# sess = tf.Session()
model = IWGAN(
    sess,
    input_width=28,
    input_height=28,
    output_width=28,
    output_height=28,
    batch_size=128,
    input_fname_pattern='*.jpg',
    checkpoint_dir= checkpoint_dir,
    samples_dir=samples_dir,
    show_samples = True,   # Turn on to show samples in Jupyter cell every 1 epoch
    epoch = 100)

# show_all_variables()
init = tf.global_variables_initializer()
sess.run(init)
sample_z = np.random.uniform(-1, 1, size=(200 , 100))
samples = model.G.eval(session = model.sess, feed_dict = {model.z: sample_z})
plt.imshow(samples[0].reshape(28,28), cmap='gray')
plt.axis('off')
plt.title('Generated sample')
plt.show()

samples = model.trX[:200]
img = grayscale_grid_vis(samples, nhw=(10,20))
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.title('Real MNIST samples')
plt.show()

model.train()
# Out:
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Incompatible shapes: [88,784] vs. [128,784]
# 	 [[Node: Mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"](Reshape, Tile)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-1-8eaf69097d2d> in <module>()
#      49 plt.show()
#      50
# ---> 51 model.train()
#
# ~/dl/DCGAN/iwgan.py in train(self)
#     118                         feed_dict={
#     119                             self.inputs: batch_images,
# --> 120                             self.z: batch_z,
#     121                         })
#     122                     self.sess.run(clip_disc_weights)
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Incompatible shapes: [88,784] vs. [128,784]
# 	 [[Node: Mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"](Reshape, Tile)]]
#
# Caused by op 'Mul', defined at:
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-8eaf69097d2d>", line 32, in <module>
#     epoch = 100)
#   File "/data/VSLab/vufg/dl/DCGAN/dcgan.py", line 72, in __init__
#     self.build_model()
#   File "/data/VSLab/vufg/dl/DCGAN/iwgan.py", line 53, in build_model
#     interpolates = tf.multiply(tf.reshape(inputs, [-1, 28 * 28]), alpha) + tf.multiply(tf.reshape(self.G,
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py", line 313, in multiply
#     return gen_math_ops._mul(x, y, name)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 1449, in _mul
#     result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2630, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/data/VSLab/vufg/miniconda3/envs/vufg_env/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1204, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Incompatible shapes: [88,784] vs. [128,784]
# 	 [[Node: Mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/cpu:0"](Reshape, Tile)]]

# %%
d_loss = model.log['d_loss']
g_loss = model.log['g_loss']
plt.plot(range(len(d_loss)), d_loss, color = 'blue', label = 'd_loss')
plt.plot(range(len(g_loss)), g_loss, color = 'red', label = 'g_loss')
plt.legend(loc="upper right")
plt.xlabel('#Epoch')
plt.ylabel('Loss')
plt.title('Training loss of D & G')
plt.show()

# %%
imgs = np.array(model.log['gen_samples'])
make_gif( imgs * 255., 'test.gif', true_image=True, duration = 2)

from IPython.display import Image
Image(url='test.gif')
